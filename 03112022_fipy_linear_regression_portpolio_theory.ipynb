# %% [markdown]
# #### Relationship between Dow Jones and KOSPI

# %%
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()


dow = pdr.get_data_yahoo('^DJI', '2000-01-04')
kospi = pdr.get_data_yahoo('^KS11', '2000-01-04')

df = pd.DataFrame({'X': dow['Close'], 'Y': kospi['Close']})
df = df.fillna(method='bfill')
df = df.fillna(method='ffill')

regr = stats.linregress(df.X, df.Y)
regr_line = f'Y = {regr.slope:.2f} * X + {regr.intercept:.2f}'

plt.figure(figsize=(7, 7))
plt.plot(df.X, df.Y, '.')
plt.plot(df.X, regr.slope * df.X + regr.intercept, 'r')
plt.legend(['DOW X KOSPI', regr_line])
plt.title(f'DOW X KOSPI (R = {regr.rvalue:.2f})')
plt.xlabel('Dow Jones Industrial Average')
plt.ylabel('KOSPI')
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# #### Relationship between Dow Jones and TLT

# %%
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()


dow = pdr.get_data_yahoo('TLT', '2000-01-04')
kospi = pdr.get_data_yahoo('^KS11', '2000-01-04')

df = pd.DataFrame({'X': dow['Close'], 'Y': kospi['Close']})
df = df.fillna(method='bfill')
df = df.fillna(method='ffill')

regr = stats.linregress(df.X, df.Y)
regr_line = f'Y = {regr.slope:.2f} * X + {regr.intercept:.2f}'

plt.figure(figsize=(7, 7))
plt.plot(df.X, df.Y, 'cx')
plt.plot(df.X, regr.slope * df.X + regr.intercept, 'r')
plt.legend(['DOW X KOSPI', regr_line])
plt.title(f'DOW X KOSPI (R = {regr.rvalue:.2f})')
plt.xlabel('Dow Jones Industrial Average')
plt.ylabel('KOSPI')
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# 포트폴리오를 만들 때 수익성의 상관관계가 되도록 -1 이 되는 두 분야를 지정해서 분산 투자 하는 것을 권한다.

# %%
import pandas as pd
s1 = pd.Series([10, -20, 30, -40,50])
s2 = pd.Series([1, -2, 3, -4,5])
s3 = pd.Series([-10, 20, -30, 40,-50])
df = pd.DataFrame({'S1': s1, 'S2': s2, 'S3': s3})

# %%
df
# Out:
#    S1  S2  S3
# 0  10   1 -10
# 1 -20  -2  20
# 2  30   3 -30
# 3 -40  -4  40
# 4  50   5 -50

# %%
df.corr()
# Out:
#      S1   S2   S3
# S1  1.0  1.0 -1.0
# S2  1.0  1.0 -1.0
# S3 -1.0 -1.0  1.0
