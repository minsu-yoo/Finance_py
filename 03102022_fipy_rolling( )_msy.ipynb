# %%
from pandas_datareader import data as pdr 
import yfinance as yf
yf.pdr_override()
import matplotlib.pyplot as plt
window = 252

kospi = pdr.get_data_yahoo('^KS11', '2004-01-04')
peak = kospi['Adj Close'].rolling(window, min_periods=1).max()
drawdown = kospi['Adj Close']/peak - 1.0
max_dd = drawdown.rolling(window, min_periods=1).min()  
#왜 최저점을 구할 때 rolling() 을 써야하지?
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
kakao =
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2004-01-05   817.280029   825.429993   816.549988   824.099976   824.099976
# 2004-01-06   831.260010   831.260010   819.530029   823.429993   823.429993
# 2004-01-07   826.080017   831.070007   825.229980   827.070007   827.070007
# 2004-01-08   831.099976   839.280029   824.150024   824.150024   824.150024
# 2004-01-09   835.419983   849.500000   835.049988   845.270020   845.270020
# ...                 ...          ...          ...          ...          ...
# 2022-03-03  2729.860107  2748.209961  2726.350098  2747.080078  2747.080078
# 2022-03-04  2736.580078  2736.580078  2702.340088  2713.429932  2713.429932
# 2022-03-07  2680.169922  2680.169922  2644.100098  2651.310059  2651.310059
# 2022-03-08  2617.330078  2647.179932  2605.810059  2622.399902  2622.399902
# 2022-03-10  2660.860107  2682.790039  2660.860107  2680.320068  2680.320068
#
#             Volume
# Date
# 2004-01-05  408300
# 2004-01-06  484100
# 2004-01-07  404600
# 2004-01-08  428800
# 2004-01-09  543300
# ...            ...
# 2022-03-03  614300
# 2022-03-04  765300
# 2022-03-07  571300
# 2022-03-08  540100
# 2022-03-10  613810
#
# [4492 rows x 6 columns]

# %%
peak
# Out:
# Date
# 2004-01-05     824.099976
# 2004-01-06     824.099976
# 2004-01-07     827.070007
# 2004-01-08     827.070007
# 2004-01-09     845.270020
#                  ...
# 2022-03-03    3305.209961
# 2022-03-04    3305.209961
# 2022-03-07    3305.209961
# 2022-03-08    3305.209961
# 2022-03-10    3305.209961
# Name: Adj Close, Length: 4492, dtype: float64

# %%
type(kospi)
# Out:
# pandas.core.frame.DataFrame

# %%
plt.figure(figsize=(9,7))
plt.subplot(211)
kospi['Close'].plot(label = 'KOSPI', title = 'KOSPI MDD', grid = True, legend=True)

plt.subplot(212)
drawdown.plot(c='blue', label = 'KOSPI DD', grid = True, legend=True)
max_dd.plot(c='red', label='KOSPI MDD', grid=True, legend=True)

plt.show()

# %%
def min_preriod(min_num):
    from pandas_datareader import data as pdr 
    import yfinance as yf
    yf.pdr_override()
    import matplotlib.pyplot as plt
    window = 252

    kospi = pdr.get_data_yahoo('^KS11', '2004-01-04')
    peak = kospi['Adj Close'].rolling(window, min_periods= min_num ).max()
    drawdown = kospi['Adj Close']/peak - 1.0
    max_dd = drawdown.rolling(window, min_periods=1).min()  
    #왜 최저점을 구할 때 rolling() 을 써야하지?  

    plt.figure(figsize=(9,7))
    plt.subplot(211)
    kospi['Close'].plot(label = 'KOSPI', title = 'KOSPI MDD', grid = True, legend=True)

    plt.subplot(212)
    drawdown.plot(c='blue', label = 'KOSPI DD', grid = True, legend=True)
    max_dd.plot(c='red', label='KOSPI MDD', grid=True, legend=True)

    plt.show()

# %%
min_preriod(1)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
min_preriod(200)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
max_dd.min()
# Out:
# -0.5453665130144085

# %%
max_dd[max_dd==-0.5453665130144085]
# Out:
# Date
# 2008-10-24   -0.545367
# 2008-10-27   -0.545367
# 2008-10-28   -0.545367
# 2008-10-29   -0.545367
# 2008-10-30   -0.545367
#                 ...
# 2009-10-16   -0.545367
# 2009-10-19   -0.545367
# 2009-10-20   -0.545367
# 2009-10-21   -0.545367
# 2009-10-22   -0.545367
# Name: Adj Close, Length: 252, dtype: float64

# %% [markdown]
# ## 3.6.1 KOSPI 와 다우존스 지수 비교

# %%
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()

dow = pdr.get_data_yahoo('^DJI', '2000-01-04')
kospi = pdr.get_data_yahoo('^KS11', '2000-01-04')

import matplotlib.pyplot as plt
plt.figure(figsize = (9,5))
plt.plot(dow.index, dow.Close, 'r--', label='Dow Jones Industrial')
plt.plot(kospi.index, kospi.Close, 'b', label='KOSPI')
plt.grid(True)
plt.legend(loc='best')
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
dow['Close']
# Out:
# Date
# 2000-01-03    11357.509766
# 2000-01-04    10997.929688
# 2000-01-05    11122.650391
# 2000-01-06    11253.259766
# 2000-01-07    11522.559570
#                   ...
# 2022-03-03    33794.660156
# 2022-03-04    33614.800781
# 2022-03-07    32817.378906
# 2022-03-08    32632.640625
# 2022-03-09    33286.250000
# Name: Close, Length: 5582, dtype: float64

# %%
dow.Close
# Out:
# Date
# 2000-01-03    11357.509766
# 2000-01-04    10997.929688
# 2000-01-05    11122.650391
# 2000-01-06    11253.259766
# 2000-01-07    11522.559570
#                   ...
# 2022-03-03    33794.660156
# 2022-03-04    33614.800781
# 2022-03-07    32817.378906
# 2022-03-08    32632.640625
# 2022-03-09    33286.250000
# Name: Close, Length: 5582, dtype: float64

# %%
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()

dow = pdr.get_data_yahoo('^DJI', '2000-01-04')
kospi = pdr.get_data_yahoo('^KS11', '2000-01-04')

d = (dow.Close/dow.Close.loc['2000-01-04'])*100
k = (kospi.Close/kospi.Close.loc['2000-01-04'])*100




import matplotlib.pyplot as plt
plt.figure(figsize = (9,5))
plt.plot(d.index, d, 'r--', label='Dow Jones Industrial Average')
plt.plot(k.index, k, 'b', label='KOSPI')
plt.grid(True)
plt.legend(loc='best')
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ### 3.6.3 산점도 분석

# %%
print(len(dow))
print(len(kospi))
# Out:
# 5582
# 5471

# %%
import pandas as pd

df = pd.DataFrame({'DOW':dow.Close, 'KOSPI':kospi.Close})

# %%
df
# Out:
#                      DOW        KOSPI
# Date
# 2000-01-03  11357.509766          NaN
# 2000-01-04  10997.929688  1059.040039
# 2000-01-05  11122.650391   986.309998
# 2000-01-06  11253.259766   960.789978
# 2000-01-07  11522.559570   948.650024
# ...                  ...          ...
# 2022-03-04  33614.800781  2713.429932
# 2022-03-07  32817.378906  2651.310059
# 2022-03-08  32632.640625  2622.399902
# 2022-03-09  33286.250000          NaN
# 2022-03-10           NaN  2680.320068
#
# [5753 rows x 2 columns]

# %%
df = df.fillna(method='bfill')

# %%
df
# Out:
#                      DOW        KOSPI
# Date
# 2000-01-03  11357.509766  1059.040039
# 2000-01-04  10997.929688  1059.040039
# 2000-01-05  11122.650391   986.309998
# 2000-01-06  11253.259766   960.789978
# 2000-01-07  11522.559570   948.650024
# ...                  ...          ...
# 2022-03-04  33614.800781  2713.429932
# 2022-03-07  32817.378906  2651.310059
# 2022-03-08  32632.640625  2622.399902
# 2022-03-09  33286.250000  2680.320068
# 2022-03-10           NaN  2680.320068
#
# [5753 rows x 2 columns]

# %%
df = df.fillna(method='ffill')

# %%
df
# Out:
#                      DOW        KOSPI
# Date
# 2000-01-03  11357.509766  1059.040039
# 2000-01-04  10997.929688  1059.040039
# 2000-01-05  11122.650391   986.309998
# 2000-01-06  11253.259766   960.789978
# 2000-01-07  11522.559570   948.650024
# ...                  ...          ...
# 2022-03-04  33614.800781  2713.429932
# 2022-03-07  32817.378906  2651.310059
# 2022-03-08  32632.640625  2622.399902
# 2022-03-09  33286.250000  2680.320068
# 2022-03-10  33286.250000  2680.320068
#
# [5753 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(7,7))
plt.scatter(df['DOW'], df['KOSPI'], marker='.')
plt.xlabel('Dow Jones Industrial Average')
plt.ylabel('KOSPI')
plt.show()

# %% [markdown]
# ### 3.6.5 선형 회귀 분석 (linear regression)

# %%
from scipy import stats
regr = stats.linregress(df['DOW'], df['KOSPI'])
regr
# Out:
# LinregressResult(slope=0.07622399082486819, intercept=466.5724746345111, rvalue=0.8223515442309665, pvalue=0.0, stderr=0.0006954393889323055, intercept_stderr=11.99758539653142)

# %%
df.corr()
# Out:
#             DOW     KOSPI
# DOW    1.000000  0.822352
# KOSPI  0.822352  1.000000
