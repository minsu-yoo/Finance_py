# %%
import pandas as pd
krx_list = pd.read_html('company_lists.xls')

# %%
krx_list[0]
# Out:
#              회사명    종목코드                   업종  \
# 0          모아데이타  288980       소프트웨어 개발 및 공급업
# 1     에스케이증권7호스팩  408920           금융 지원 서비스업
# 2             노을  376930           의료용 기기 제조업
# 3           비씨엔씨  146320              반도체 제조업
# 4           풍원정밀  371950             전자부품 제조업
# ...          ...     ...                  ...
# 2494      CJ대한통운     120            도로 화물 운송업
# 2495       메리츠화재      60                  보험업
# 2496          경방      50               종합 소매업
# 2497       유수홀딩스     700  회사 본부 및 경영 컨설팅 서비스업
# 2498    한진중공업홀딩스    3480    연료용 가스 제조 및 배관공급업
#
#                                                    주요제품         상장일  결산월  \
# 0                         인공지능 기반 ICT 시스템 이상탐지 및 예측 솔루션  2022-03-10  12월
# 1                                                기업인수합병  2022-03-07  12월
# 2                                          융복합 체외진단 플랫폼  2022-03-03  12월
# 3                                        반도체용 합성쿼츠 포커스링  2022-03-03  12월
# 4                                   OLED 증착용 Metal Mask  2022-02-28  12월
# ...                                                 ...         ...  ...
# 2494  Contract Logistics, 포워딩, 항만하역, 해운, 택배국제특송, SCM...  1956-07-02  12월
# 2495                                   손해보험(화재,해상,운송보험)  1956-07-02  12월
# 2496          섬유류(면사,면혼방사,면직물,면혼방직물,화섬사,화섬직물) 제조,도매,수출입  1956-03-03  12월
# 2497                                               지주사업  1956-03-03  12월
# 2498                                               지주회사  1956-03-03  12월
#
#           대표자명                          홈페이지     지역
# 0          한상진      http://www.moadata.co.kr    경기도
# 1          권치완                           NaN  서울특별시
# 2     임찬양, 이동영                       noul.kr    경기도
# 3          김돈한         http://www.bcnc.co.kr    경기도
# 4          유명훈           http://poongwon.com    경기도
# ...        ...                           ...    ...
# 2494       강신호    http://www.cjlogistics.com  서울특별시
# 2495       김용범     http://www.meritzfire.com  서울특별시
# 2496    김준, 김담    http://www.kyungbang.co.kr  서울특별시
# 2497       송영규  http://www.eusu-holdings.com  서울특별시
# 2498  조남호, 조원국  http://www.hhic-holdings.com    경기도
#
# [2499 rows x 9 columns]

# %%
krx_list[0].종목코드 = krx_list[0].종목코드.map('{:06d}'.format)

# %%
krx_list[0]
# Out:
#              회사명    종목코드                   업종  \
# 0          모아데이타  288980       소프트웨어 개발 및 공급업
# 1     에스케이증권7호스팩  408920           금융 지원 서비스업
# 2             노을  376930           의료용 기기 제조업
# 3           비씨엔씨  146320              반도체 제조업
# 4           풍원정밀  371950             전자부품 제조업
# ...          ...     ...                  ...
# 2494      CJ대한통운  000120            도로 화물 운송업
# 2495       메리츠화재  000060                  보험업
# 2496          경방  000050               종합 소매업
# 2497       유수홀딩스  000700  회사 본부 및 경영 컨설팅 서비스업
# 2498    한진중공업홀딩스  003480    연료용 가스 제조 및 배관공급업
#
#                                                    주요제품         상장일  결산월  \
# 0                         인공지능 기반 ICT 시스템 이상탐지 및 예측 솔루션  2022-03-10  12월
# 1                                                기업인수합병  2022-03-07  12월
# 2                                          융복합 체외진단 플랫폼  2022-03-03  12월
# 3                                        반도체용 합성쿼츠 포커스링  2022-03-03  12월
# 4                                   OLED 증착용 Metal Mask  2022-02-28  12월
# ...                                                 ...         ...  ...
# 2494  Contract Logistics, 포워딩, 항만하역, 해운, 택배국제특송, SCM...  1956-07-02  12월
# 2495                                   손해보험(화재,해상,운송보험)  1956-07-02  12월
# 2496          섬유류(면사,면혼방사,면직물,면혼방직물,화섬사,화섬직물) 제조,도매,수출입  1956-03-03  12월
# 2497                                               지주사업  1956-03-03  12월
# 2498                                               지주회사  1956-03-03  12월
#
#           대표자명                          홈페이지     지역
# 0          한상진      http://www.moadata.co.kr    경기도
# 1          권치완                           NaN  서울특별시
# 2     임찬양, 이동영                       noul.kr    경기도
# 3          김돈한         http://www.bcnc.co.kr    경기도
# 4          유명훈           http://poongwon.com    경기도
# ...        ...                           ...    ...
# 2494       강신호    http://www.cjlogistics.com  서울특별시
# 2495       김용범     http://www.meritzfire.com  서울특별시
# 2496    김준, 김담    http://www.kyungbang.co.kr  서울특별시
# 2497       송영규  http://www.eusu-holdings.com  서울특별시
# 2498  조남호, 조원국  http://www.hhic-holdings.com    경기도
#
# [2499 rows x 9 columns]

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen 

url = 'https://finance.naver.com/item/sise_day.naver?code=068270&page=1'
with urlopen(url) as doc:
    html = BeautifulSoup(doc, 'lxml')
    pgrr = html.find('td', class_='pgRR')
    print(pgrr.a['href'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-d318fe52e29b> in <module>
#       6     html = BeautifulSoup(doc, 'lxml')
#       7     pgrr = html.find('td', class_='pgRR')
# ----> 8     print(pgrr.a['href'])
#       9
#
# AttributeError: 'NoneType' object has no attribute 'a'

# %%
type(html)
# Out:
# bs4.BeautifulSoup

# %%
# Out:
# bs4.BeautifulSoup
