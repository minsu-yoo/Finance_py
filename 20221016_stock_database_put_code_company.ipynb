# %%
import FinanceDataReader as fdr
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = 'http://kind.krx.co.kr/corpgeneral/corpList.do?method='\
            'download&searchType=13'
krx = pd.read_html(url, header=0)[0]
krx = krx[['종목코드', '회사명']]
krx = krx.rename(columns={'종목코드': 'code', '회사명': 'company'})
krx.code = krx.code.map('{:06d}'.format)

# %%
krx_stocklist = fdr.StockListing('KRX')

# %%
code_row = krx.loc[krx['code'] == '000210']

# %%
code_row['company']
# Out:
# 0    DL
# Name: company, dtype: object

# %%
krx['code']== '000210'
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2531    False
# 2532    False
# 2533    False
# 2534    False
# 2535    False
# Name: code, Length: 2536, dtype: bool

# %%
krx['code'][0]
# Out:
# '000210'

# %%
data_list = []

# %%
list(krx.loc[:,'code'])
# Out:
# ['000210',
#  '004840',
#  '155660',
#  '078930',
#  '294870',
#  '001390',
#  '025000',
#  '044450',
#  '058860',
#  '011070',
#  '037560',
#  '108670',
#  '383800',
#  '023150',
#  '010060',
#  '178920',
#  '402340',
#  '096770',
#  '011810',
#  '024070',
#  '011420',
#  '002100',
#  '012320',
#  '007690',
#  '014530',
#  '090350',
#  '005250',
#  '353200',
#  '128820',
#  '047040',
#  '000430',
#  '000020',
#  '336260',
#  '286940',
#  '008560',
#  '000060',
#  '017180',
#  '012690',
#  '204210',
#  '003850',
#  '001270',
#  '030790',
#  '028050',
#  '005930',
#  '068290',
#  '003230',
#  '003720',
#  '004380',
#  '010960',
#  '136490',
#  '002420',
#  '004490',
#  '016590',
#  '029530',
#  '031430',
#  '293940',
#  '055550',
#  '078520',
#  '012280',
#  '007310',
#  '271560',
#  '105840',
#  '008600',
#  '033270',
#  '023800',
#  '129260',
#  '013360',
#  '081000',
#  '033240',
#  '271980',
#  '002620',
#  '001550',
#  '001630',
#  '272450',
#  '009070',
#  '417310',
# ...

# %%
df_1 = fdr.DataReader(krx['code'][0], '2000', '2023')

df_1['Code'] = krx['code'][0]
df_1['Company'] = krx['company'][0]





#code_row = krx.loc[krx['code'] == '000210']

# %%
df_2 = fdr.DataReader(krx['code'][1], '2000', '2023')

df_2['Code'] = krx['code'][1]
df_2['Company'] = krx['company'][1]

# 



#code_row = krx.loc[krx['code'] == '000210']

# %%
df_2
# Out:
#             Open  High   Low  Close  Volume    Change    Code Company
# Date
# 2000-01-04  1042  1042   925   1016    2500 -0.028681  004840   DRB동일
# 2000-01-05  1024  1024  1001   1007     200 -0.008858  004840   DRB동일
# 2000-01-06  1001  1001  1001   1007       0  0.000000  004840   DRB동일
# 2000-01-07   937   981   937    984    2100 -0.022840  004840   DRB동일
# 2000-01-10   978   978   978    980    1800 -0.004065  004840   DRB동일
# ...          ...   ...   ...    ...     ...       ...     ...     ...
# 2022-10-07  4245  4375  4205   4295    7752  0.021403  004840   DRB동일
# 2022-10-11  4295  4295  4055   4115    8872 -0.041909  004840   DRB동일
# 2022-10-12  4015  4085  4015   4085   19295 -0.007290  004840   DRB동일
# 2022-10-13  4050  4065  3890   3945   31261 -0.034272  004840   DRB동일
# 2022-10-14  4000  4070  4000   4045   11265  0.025349  004840   DRB동일
#
# [5624 rows x 8 columns]

# %%
df_1
# Out:
#              Open   High    Low  Close  Volume    Change    Code Company
# Date
# 2000-01-04   9668  12108   9668  11205  484170  0.016419  000210      DL
# 2000-01-05  11024  11024  10210  10392  440630 -0.072557  000210      DL
# 2000-01-06  10662  10798   9578   9849  499050 -0.052252  000210      DL
# 2000-01-07   9849  10120   9578  10030  554370  0.018378  000210      DL
# 2000-01-10  10120  10210   9668   9940  533930 -0.008973  000210      DL
# ...           ...    ...    ...    ...     ...       ...     ...     ...
# 2022-10-07  59100  59700  58500  59500   55000 -0.001678  000210      DL
# 2022-10-11  58000  59000  56700  57000   68217 -0.042017  000210      DL
# 2022-10-12  56900  59800  56400  58700   60551  0.029825  000210      DL
# 2022-10-13  58700  58800  56500  56500   42079 -0.037479  000210      DL
# 2022-10-14  57500  58900  57200  58600   38238  0.037168  000210      DL
#
# [5624 rows x 8 columns]

# %%
df_2
# Out:
#             Open  High   Low  Close  Volume    Change    Code Company
# Date
# 2000-01-04  1042  1042   925   1016    2500 -0.028681  004840   DRB동일
# 2000-01-05  1024  1024  1001   1007     200 -0.008858  004840   DRB동일
# 2000-01-06  1001  1001  1001   1007       0  0.000000  004840   DRB동일
# 2000-01-07   937   981   937    984    2100 -0.022840  004840   DRB동일
# 2000-01-10   978   978   978    980    1800 -0.004065  004840   DRB동일
# ...          ...   ...   ...    ...     ...       ...     ...     ...
# 2022-10-07  4245  4375  4205   4295    7752  0.021403  004840   DRB동일
# 2022-10-11  4295  4295  4055   4115    8872 -0.041909  004840   DRB동일
# 2022-10-12  4015  4085  4015   4085   19295 -0.007290  004840   DRB동일
# 2022-10-13  4050  4065  3890   3945   31261 -0.034272  004840   DRB동일
# 2022-10-14  4000  4070  4000   4045   11265  0.025349  004840   DRB동일
#
# [5624 rows x 8 columns]

# %%
df_3 = pd.merge(df_1, df_2)

# %%
frames = [df_1, df_2]

# %%
frames
# Out:
# [             Open   High    Low  Close  Volume    Change    Code Company
#  Date
#  2000-01-04   9668  12108   9668  11205  484170  0.016419  000210      DL
#  2000-01-05  11024  11024  10210  10392  440630 -0.072557  000210      DL
#  2000-01-06  10662  10798   9578   9849  499050 -0.052252  000210      DL
#  2000-01-07   9849  10120   9578  10030  554370  0.018378  000210      DL
#  2000-01-10  10120  10210   9668   9940  533930 -0.008973  000210      DL
#  ...           ...    ...    ...    ...     ...       ...     ...     ...
#  2022-10-07  59100  59700  58500  59500   55000 -0.001678  000210      DL
#  2022-10-11  58000  59000  56700  57000   68217 -0.042017  000210      DL
#  2022-10-12  56900  59800  56400  58700   60551  0.029825  000210      DL
#  2022-10-13  58700  58800  56500  56500   42079 -0.037479  000210      DL
#  2022-10-14  57500  58900  57200  58600   38238  0.037168  000210      DL
#
#  [5624 rows x 8 columns],
# ...

# %%
result = pd.concat(frames)

# %%
result
# Out:
#              Open   High    Low  Close  Volume    Change    Code Company
# Date
# 2000-01-04   9668  12108   9668  11205  484170  0.016419  000210      DL
# 2000-01-05  11024  11024  10210  10392  440630 -0.072557  000210      DL
# 2000-01-06  10662  10798   9578   9849  499050 -0.052252  000210      DL
# 2000-01-07   9849  10120   9578  10030  554370  0.018378  000210      DL
# 2000-01-10  10120  10210   9668   9940  533930 -0.008973  000210      DL
# ...           ...    ...    ...    ...     ...       ...     ...     ...
# 2022-10-07   4245   4375   4205   4295    7752  0.021403  004840   DRB동일
# 2022-10-11   4295   4295   4055   4115    8872 -0.041909  004840   DRB동일
# 2022-10-12   4015   4085   4015   4085   19295 -0.007290  004840   DRB동일
# 2022-10-13   4050   4065   3890   3945   31261 -0.034272  004840   DRB동일
# 2022-10-14   4000   4070   4000   4045   11265  0.025349  004840   DRB동일
#
# [11248 rows x 8 columns]

# %%
df_3
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Change, Code, Company]
# Index: []

# %%
data_list.append(df_1)

# %% [markdown]
# list 에 append 를 써야 덩어리의 데이터를 list 로 넣을 수 있다.

# %%
data_list[0]
# Out:
#              Open   High    Low  Close  Volume    Change
# Date
# 2000-01-04   9668  12108   9668  11205  484170  0.016419
# 2000-01-05  11024  11024  10210  10392  440630 -0.072557
# 2000-01-06  10662  10798   9578   9849  499050 -0.052252
# 2000-01-07   9849  10120   9578  10030  554370  0.018378
# 2000-01-10  10120  10210   9668   9940  533930 -0.008973
# ...           ...    ...    ...    ...     ...       ...
# 2022-10-07  59100  59700  58500  59500   55000 -0.001678
# 2022-10-11  58000  59000  56700  57000   68217 -0.042017
# 2022-10-12  56900  59800  56400  58700   60551  0.029825
# 2022-10-13  58700  58800  56500  56500   42079 -0.037479
# 2022-10-14  57500  58900  57200  58600   38238  0.037168
#
# [5624 rows x 6 columns]

# %%
data_list[0] = fdr.DataReader(krx['code'][0], '2005', '2022')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 data_list[0] = fdr.DataReader(krx['code'][0], '2005', '2022')
#
# IndexError: list assignment index out of range
