# %%
import FinanceDataReader as fdr

# %%
krx_data = fdr.StockListing('KRX')

# %%
krx_data
# Out:
#       Symbol  Market              Name         Sector  \
# 0     060310  KOSDAQ                3S       전자부품 제조업
# 1     105190   KOSPI           ACE 200            NaN
# 2     332500   KOSPI         ACE 200TR            NaN
# 3     385590   KOSPI        ACE ESG액티브            NaN
# 4     380340   KOSPI       ACE Fn5G플러스            NaN
# ...      ...     ...               ...            ...
# 7024  435550   KOSPI   히어로즈 TDF2050액티브            NaN
# 7025  437550   KOSPI  히어로즈 글로벌리츠이지스액티브            NaN
# 7026  419890   KOSPI   히어로즈 단기채권ESG액티브            NaN
# 7027  429870   KOSPI     히어로즈 리츠이지스액티브            NaN
# 7028  238490  KOSDAQ                힘스  특수 목적용 기계 제조업
#
#                             Industry ListingDate SettleMonth Representative  \
# 0                        반도체 웨이퍼 캐리어  2002-04-23         03월            김세완
# 1                                NaN         NaT         NaN            NaN
# 2                                NaN         NaT         NaN            NaN
# 3                                NaN         NaT         NaN            NaN
# 4                                NaN         NaT         NaN            NaN
# ...                              ...         ...         ...            ...
# 7024                             NaN         NaT         NaN            NaN
# 7025                             NaN         NaT         NaN            NaN
# 7026                             NaN         NaT         NaN            NaN
# 7027                             NaN         NaT         NaN            NaN
# 7028  OLED Mask 인장기, OLED Mask 검사기 등  2017-07-20         12월            김주환
#
#                    HomePage Region
# 0      http://www.3sref.com  서울특별시
# 1                       NaN    NaN
# 2                       NaN    NaN
# 3                       NaN    NaN
# 4                       NaN    NaN
# ...                     ...    ...
# 7024                    NaN    NaN
# 7025                    NaN    NaN
# 7026                    NaN    NaN
# 7027                    NaN    NaN
# 7028  http://www.hims.co.kr  인천광역시
#
# [7029 rows x 10 columns]

# %%
snp_data = fdr.StockListing('S&P500')
# Out:
# /Users/minsuyoo/opt/anaconda3/lib/python3.9/site-packages/FinanceDataReader/wikipedia/listing.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Symbol'] = df['Symbol'].str.replace('\.', '')

# %%
snp_data
# Out:
#     Symbol                  Name                  Sector  \
# 0      MMM                    3M             Industrials
# 1      AOS           A. O. Smith             Industrials
# 2      ABT                Abbott             Health Care
# 3     ABBV                AbbVie             Health Care
# 4     ABMD               Abiomed             Health Care
# ..     ...                   ...                     ...
# 498    YUM           Yum! Brands  Consumer Discretionary
# 499   ZBRA    Zebra Technologies  Information Technology
# 500    ZBH         Zimmer Biomet             Health Care
# 501   ZION  Zions Bancorporation              Financials
# 502    ZTS                Zoetis             Health Care
#
#                                Industry
# 0              Industrial Conglomerates
# 1                     Building Products
# 2                 Health Care Equipment
# 3                       Pharmaceuticals
# 4                 Health Care Equipment
# ..                                  ...
# 498                         Restaurants
# 499  Electronic Equipment & Instruments
# 500               Health Care Equipment
# 501                      Regional Banks
# 502                     Pharmaceuticals
#
# [503 rows x 4 columns]

# %%
naver_symbol = krx_data.loc[krx_data.Name == 'NAVER', ['Symbol']].values[0][0]

# %%
naver_symbol
# Out:
# '035420'

# %%
naver_df = fdr.DataReader(naver_symbol, '2005', '2022')

# %%
naver_df
# Out:
#               Open    High     Low   Close  Volume    Change
# Date
# 2005-01-03    8937    9189    8822    9158  260145  0.044361
# 2005-01-04    9084    9136    8884    9032  184464 -0.013758
# 2005-01-05    8884    8969    8759    8927  144980 -0.011625
# 2005-01-06    8968    9387    8800    8979  611313  0.005825
# 2005-01-07    9053    9295    9021    9285  376900  0.034080
# ...            ...     ...     ...     ...     ...       ...
# 2021-12-24  378000  388000  378000  384000  412695  0.015873
# 2021-12-27  384500  384500  380000  380500  226757 -0.009115
# 2021-12-28  380000  385500  378000  384500  551228  0.010512
# 2021-12-29  389000  389000  382000  382000  352409 -0.006502
# 2021-12-30  381000  382000  376000  378500  369314 -0.009162
#
# [4205 rows x 6 columns]

# %%
import yfinance as yf

# %%
yf.download('SPY', start='2000-01-01', end = '2022-09-07',
           progress = False,
           auto_adjust = False, 
           actions = 'inline')
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1999-12-31  146.843750  147.500000  146.250000  146.875000   96.692841
# 2000-01-03  148.250000  148.250000  143.875000  145.437500   95.746490
# 2000-01-04  143.531250  144.062500  139.640625  139.750000   92.002197
# 2000-01-05  139.937500  141.531250  137.250000  140.000000   92.166748
# 2000-01-06  139.625000  141.500000  137.750000  137.750000   90.685501
# ...                ...         ...         ...         ...         ...
# 2022-08-30  403.850006  404.100006  396.000000  398.209991  396.580902
# 2022-08-31  399.929993  401.239990  395.040009  395.179993  393.563293
# 2022-09-01  392.890015  396.779999  390.040009  396.420013  394.798248
# 2022-09-02  400.279999  401.559998  390.329987  392.239990  390.635315
# 2022-09-06  393.130005  394.119995  388.420013  390.760010  389.161407
#
#               Volume  Dividends  Stock Splits
# Date
# 1999-12-31   3172700        0.0             0
# 2000-01-03   8164300        0.0             0
# 2000-01-04   8089800        0.0             0
# 2000-01-05  12177900        0.0             0
# 2000-01-06   6227200        0.0             0
# ...              ...        ...           ...
# 2022-08-30  85652400        0.0             0
# 2022-08-31  76029700        0.0             0
# 2022-09-01  78740100        0.0             0
# 2022-09-02  99574100        0.0             0
# 2022-09-06  76637400        0.0             0
#
# [5707 rows x 8 columns]

# %%
yf.download('IEF', start='2000-01-01', end = '2022-09-07',
           progress = False,
           auto_adjust = False, 
           actions = 'inline')
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2002-07-30   81.940002   82.120003   81.699997   81.769997   45.951408
# 2002-07-31   82.050003   82.580002   82.050003   82.519997   46.372845
# 2002-08-01   82.540001   82.900002   82.519997   82.860001   46.563908
# 2002-08-02   83.019997   83.699997   82.900002   83.500000   46.923573
# 2002-08-05   83.680000   83.919998   83.529999   83.919998   47.159580
# ...                ...         ...         ...         ...         ...
# 2022-08-30  101.389999  101.720001  101.019997  101.360001  100.983139
# 2022-08-31  101.209999  101.440002  100.769997  100.940002  100.564705
# 2022-09-01  100.089996  100.309998   99.730003   99.959999   99.765266
# 2022-09-02  100.360001  100.790001  100.220001  100.519997  100.324173
# 2022-09-06   99.910004   99.940002   99.349998   99.400002   99.206360
#
#               Volume  Dividends  Stock Splits
# Date
# 2002-07-30     41300      0.000             0
# 2002-07-31     32600      0.000             0
# 2002-08-01     71400      0.000             0
# 2002-08-02    120300      0.000             0
# 2002-08-05    159300      0.000             0
# ...              ...        ...           ...
# 2022-08-30   4474200      0.000             0
# 2022-08-31   5797600      0.000             0
# 2022-09-01  10324200      0.179             0
# 2022-09-02   5741900      0.000             0
# 2022-09-06   6769400      0.000             0
#
# [5062 rows x 8 columns]

# %%
yf.download('TLT', start='2000-01-01', end = '2022-09-07',
           progress = False,
           auto_adjust = False, 
           actions = 'inline')
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2002