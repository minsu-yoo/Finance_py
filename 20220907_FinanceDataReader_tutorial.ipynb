# %%
import FinanceDataReader as fdr

# %%
krx_data = fdr.StockListing('KRX')

# %%
krx_data
# Out:
#       Symbol  Market              Name           Sector  \
# 0     060310  KOSDAQ                3S         전자부품 제조업
# 1     095570   KOSPI            AJ네트웍스  산업용 기계 및 장비 임대업
# 2     006840   KOSPI             AK홀딩스           기타 금융업
# 3     054620  KOSDAQ            APS홀딩스           기타 금융업
# 4     265520  KOSDAQ             AP시스템    특수 목적용 기계 제조업
# ...      ...     ...               ...              ...
# 8312  435550   KOSPI   히어로즈 TDF2050액티브              NaN
# 8313  437550   KOSPI  히어로즈 글로벌리츠이지스액티브              NaN
# 8314  419890   KOSPI   히어로즈 단기채권ESG액티브              NaN
# 8315  429870   KOSPI     히어로즈 리츠이지스액티브              NaN
# 8316  238490  KOSDAQ                힘스    특수 목적용 기계 제조업
#
#                             Industry ListingDate SettleMonth  \
# 0                        반도체 웨이퍼 캐리어  2002-04-23         03월
# 1                렌탈(파렛트, OA장비, 건설장비)  2015-08-21         12월
# 2                               지주사업  1999-08-11         12월
# ...

# %%
snp_data = fdr.StockListing('S&P500')
# Out:
# /Users/minsuyoo/opt/anaconda3/lib/python3.9/site-packages/FinanceDataReader/wikipedia/listing.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Symbol'] = df['Symbol'].str.replace('\.', '')

# %%
snp_data
# Out:
#     Symbol                  Name                  Sector  \
# 0      MMM                    3M             Industrials
# 1      AOS           A. O. Smith             Industrials
# 2      ABT                Abbott             Health Care
# 3     ABBV                AbbVie             Health Care
# 4     ABMD               Abiomed             Health Care
# ..     ...                   ...                     ...
# 498    YUM           Yum! Brands  Consumer Discretionary
# 499   ZBRA    Zebra Technologies  Information Technology
# 500    ZBH         Zimmer Biomet             Health Care
# 501   ZION  Zions Bancorporation              Financials
# 502    ZTS                Zoetis             Health Care
#
#                                Industry
# 0              Industrial Conglomerates
# 1                     Building Products
# 2                 Health Care Equipment
# 3                       Pharmaceuticals
# 4                 Health Care Equipment
# ...

# %%
naver_symbol = krx_data.loc[krx_data.Name == 'NAVER', ['Symbol']].values[0][0]

# %%
naver_df = fdr.DataReader(naver_symbol, '2005', '2022')

# %%
naver_df
# Out:
#               Open    High     Low   Close  Volume    Change
# Date
# 2005-01-03    8937    9189    8822    9158  260145  0.044361
# 2005-01-04    9084    9136    8884    9032  184464 -0.013758
# 2005-01-05    8884    8969    8759    8927  144980 -0.011625
# 2005-01-06    8968    9387    8800    8979  611313  0.005825
# 2005-01-07    9053    9295    9021    9285  376900  0.034080
# ...            ...     ...     ...     ...     ...       ...
# 2021-12-24  378000  388000  378000  384000  412695  0.015873
# 2021-12-27  384500  384500  380000  380500  226757 -0.009115
# 2021-12-28  380000  385500  378000  384500  551228  0.010512
# 2021-12-29  389000  389000  382000  382000  352409 -0.006502
# 2021-12-30  381000  382000  376000  378500  369314 -0.009162
#
# [4205 rows x 6 columns]

# %%
from Investa import Analyzer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [35], in <cell line: 1>()
# ----> 1 from Investa import Analyzer
#
# ModuleNotFoundError: No module named 'Investa'

# %%
spy_data = fdr.StockListing('SPY')
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 spy_data = fdr.StockListing('SPY')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/FinanceDataReader/data.py:79, in StockListing(market)
#      77 else:
#      78     msg = "market='%s' is not implemented" % market
# ---> 79     raise NotImplementedError(msg)
#
# NotImplementedError: market='SPY' is not implemented

# %%
import yfinance as yf

# %%
yf.download('SPY', start='2000-01-01', end = '2022-09-07',
           progress = False,
           auto_adjust = False, 
           actions = 'inline')
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1999-12-31  146.843750  147.500000  146.250000  146.875000   97.090019
# 2000-01-03  148.250000  148.250000  143.875000  145.437500   96.139778
# 2000-01-04  143.531250  144.062500  139.640625  139.750000   92.380127
# 2000-01-05  139.937500  141.531250  137.250000  140.000000   92.545403
# 2000-01-06  139.625000  141.500000  137.750000  137.750000   91.058044
# ...                ...         ...         ...         ...         ...
# 2022-08-30  403.850006  404.100006  396.000000  398.209991  398.209991
