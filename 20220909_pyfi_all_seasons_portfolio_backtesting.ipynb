# %%
import yfinance as yf

# %%
spy = yf.download('SPY', start='1970-01-01', end = '2022-09-07',
           progress = False,
           auto_adjust = False, 
           actions = 'inline')

# %%
ief = yf.download('IEF', start='1970-01-01', end = '2022-09-07',
           progress = False,
           auto_adjust = False, 
           actions = 'inline')

# %%
tlt = yf.download('TLT', start='1970-01-01', end = '2022-09-07',
           progress = False,
           auto_adjust = False, 
           actions = 'inline')

# %%
dbc = yf.download('DBC', start='1970-01-01', end = '2022-09-07',
           progress = False,
           auto_adjust = False, 
           actions = 'inline')

# %%
gld = yf.download('GLD', start='1970-01-01', end = '2022-09-07',
           progress = False,
           auto_adjust = False, 
           actions = 'inline')

# %%
gld
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2004-11-18   44.430000   44.490002   44.070000   44.380001   44.380001
# 2004-11-19   44.490002   44.919998   44.470001   44.779999   44.779999
# 2004-11-22   44.750000   44.970001   44.740002   44.950001   44.950001
# 2004-11-23   44.880001   44.919998   44.720001   44.750000   44.750000
# 2004-11-24   44.930000   45.049999   44.790001   45.049999   45.049999
# ...                ...         ...         ...         ...         ...
# 2022-08-30  161.270004  161.429993  160.339996  160.509995  160.509995
# 2022-08-31  159.500000  160.570007  159.259995  159.270004  159.270004
# 2022-09-01  158.169998  158.389999  157.320007  157.869995  157.869995
# 2022-09-02  159.350006  160.059998  159.139999  159.259995  159.259995
# 2022-09-06  159.169998  159.460007  158.320007  158.330002  158.330002
#
#               Volume  Dividends  Stock Splits
# Date
# 2004-11-18   5992000          0             0
# ...

# %%
gld['Close'].plot(label='Gold', grid=True, legend=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
spy['Close'].plot(title = 'USA stock', grid=True)
# Out:
# <AxesSubplot:title={'center':'USA stock'}, xlabel='Date'>

# %%
ief['Close'].plot(label='ief', grid=True, legend=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
dbc['Close'].plot(title = 'DBC', grid=True)
# Out:
# <AxesSubplot:title={'center':'DBC'}, xlabel='Date'>

# %%
tlt['Close'].plot(title = 'longterm bond', grid=True)
tlt['Close'].plot(title = 'longterm bond', grid=True)
# Out:
# <AxesSubplot:title={'center':'longterm bond'}, xlabel='Date'>

# %%
import matplotlib.pyplot as plt
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()


sec = pdr.get_data_yahoo('005930.KS', start='2019-03-06')
sec_dpc = (sec['Close']/sec['Close'].shift(1) - 1)*100
sec_dpc.iloc[0] = 0
sec_dpc_cs = sec_dpc.cumsum()


msft = pdr.get_data_yahoo('MSFT', start='2019-03-06')
msft_dpc = (msft['Close']/msft['Close'].shift(1) - 1)*100
msft_dpc.iloc[0] = 0
msft_dpc_cs = msft_dpc.cumsum()


plt.plot(sec.index, msft_dpc_cs, 'b', label='Samsung Electronics')
plt.plot(msft.index, msft_dpc_cs, 'r--', label='Samsung Electronics')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [27], in <cell line: 19>()
#      15 msft_dpc.iloc[0] = 0
#      16 msft_dpc_cs = msft_dpc.cumsum()
# ---> 19 plt.plot(sec.index, msft_dpc_cs, 'b', label='Samsung Electronics')
#      20 plt.plot(msft.index, msft_dpc_cs, 'r--', label='Samsung Electronics')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:2757, in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# ...

# %%
type(gld.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
msft_dpc = (gld['Close']/gld['Close'].shift(1) - 1)*100
msft_dpc.iloc[0] = 0
msft_dpc_cs = msft_dpc.cumsum()


plt.plot(gld.index, msft_dpc_cs, 'b', label='Samsung Electronics')
#plt.plot(msft.index, msft_dpc_cs, 'r--', label='Samsung Electronics')

# %%
def growth_rate(data):
    
    msft_dpc = (data['Close']/data['Close'].shift(1) - 1)*100
    msft_dpc.iloc[0] = 0
    msft_dpc_cs = msft_dpc.cumsum()


    plt.plot(data.index, msft_dpc_cs, 'b', label='Samsung Electronics')
    #plt.plot(msft.index, msft_dpc_cs, 'r--', label='Samsung Electronics')

# %%
# Out:
# Date
# 1993-01-29           NaN
# 1993-02-01     43.937500
# 1993-02-02     44.250000
# 1993-02-03     44.343750
# 1993-02-04     44.812500
#                  ...
# 2022-08-30    402.630005
# 2022-08-31    398.209991
# 2022-09-01    395.179993
# 2022-09-02    396.420013
# 2022-09-06    392.239990
# Name: Close, Length: 7455, dtype: float64

# %%
growth_rate(spy)

# %%
import matplotlib.pyplot as plt

# %%
a = str(spy.index[0])
first_day  = a[:10]

# %%
s  = (spy.Close / spy.Close.loc['2010-01-04'])*100

# %%
plt.style.use('https://raw.githubusercontent.com/NeuromatchAcademy/course-content/master/nma.mplstyle')

# %%
plt.plot(s)
